# %% [markdown]
# # Problem 1 Production economy and CO2 taxation

# %% [markdown]
# ## Question 1

# %%
import numpy as np
from types import SimpleNamespace
import pandas as pd

# We start by defining the parameters
par = SimpleNamespace()
par.A = 1.0
par.gamma = 0.5
par.alpha = 0.3
par.nu = 1.0
par.epsilon = 2.0
par.tau = 0.0
par.T = 0.0


# First we create the function to calculate optimal labor and output
def optimal_labor_output(w, p, A, gamma):
    labor = (p * A * gamma / w) ** (1 / (1 - gamma))
    output = A * labor ** gamma
    return labor, output

# Now we create the function to calculate profits
def profits(w, p, A, gamma):
    labor, output = optimal_labor_output(w, p, A, gamma)
    profit = p * output - w * labor
    return profit

# Next we create the function to calculate consumer behavior
def consumer_behavior(w, p1, p2, tau, T, alpha, nu, epsilon, A, gamma):
    # Optimal labor and output for both firms
    labor1, output1 = optimal_labor_output(w, p1, A, gamma)
    labor2, output2 = optimal_labor_output(w, p2 + tau, A, gamma)

# Next we define profits from both firms
    profit1 = profits(w, p1, A, gamma)
    profit2 = profits(w, p2, A, gamma)
    
    # Total income
    income = w * (labor1 + labor2) + T + profit1 + profit2
    
    # Optimal consumption
    c1 = alpha * income / p1
    c2 = (1 - alpha) * income / (p2 + tau)
    
    return labor1, labor2, output1, output2, c1, c2

# Create the function to check market clearing conditions
def check_market_clearing(w, p1_vals, p2_vals, par):
    results = [] # Creating empty list 
    for p1 in p1_vals: # Loop through different price combinations
        for p2 in p2_vals:
            labor1, labor2, output1, output2, c1, c2 = consumer_behavior(
                w, p1, p2, par.tau, par.T, par.alpha, par.nu, par.epsilon, par.A, par.gamma)
           # Next we make sure that the market clearing requirements are uphold
            market_clearing = {
                "p1": p1,
                "p2": p2,
                "Labor Market Clearing": np.isclose(labor1 + labor2, labor1 + labor2),
                "Good 1 Market Clearing": np.isclose(c1, output1),
                "Good 2 Market Clearing": np.isclose(c2, output2)
            }
            results.append(market_clearing)
    return results

# Define the price ranges and numeraire given in the assingment
w = 1.0
p_vals = np.linspace(0.1, 2.0, 10)

# This generates 10 equally spaced values between 0.1 and 2.0 for both p1 and p2, which we will

# Next we check market clearing conditions
market_clearing_results = check_market_clearing(w, p_vals, p_vals, par)

# Next we convert the results to a DataFrame
market_clearing_df = pd.DataFrame(market_clearing_results)

# Finally we display the DataFrame
market_clearing_df
# Out:
#      p1        p2  Labor Market Clearing  Good 1 Market Clearing  \
# 0   0.1  0.100000                   True                   False
# 1   0.1  0.311111                   True                   False
# 2   0.1  0.522222                   True                   False
# 3   0.1  0.733333                   True                   False
# 4   0.1  0.944444                   True                   False
# ..  ...       ...                    ...                     ...
# 95  2.0  1.155556                   True                   False
# 96  2.0  1.366667                   True                   False
# 97  2.0  1.577778                   True                   False
# 98  2.0  1.788889                   True                   False
# 99  2.0  2.000000                   True                   False
#
#     Good 2 Market Clearing
# 0                    False
# 1                    False
# 2                    False
# 3                    False
# 4                    False
# ..                     ...
# 95                   False
# 96                   False
# 97                   False
# 98                   False
# 99                   False
#
# [100 rows x 5 columns]

# %% [markdown]
# This indicates that with the given parameters and price ranges, the market for neither Good 1 nor Good 2 reaches equilibrium. Therefore, we can conclude that under the current conditions and assumptions, there are no price combinations within the specified ranges that lead to both goods markets clearing simultaneously.

# %% [markdown]
# ## Question 2

# %%
import numpy as np
import pandas as pd
from types import SimpleNamespace

# Define the parameters
par = SimpleNamespace()
par.A = 1.0
par.gamma = 0.5
par.alpha = 0.3
par.nu = 1.0
par.epsilon = 2.0
par.tau = 0.0
par.T = 0.0

# Define the functions from Question 1
def optimal_labor_output(w, p, A, gamma):
    labor = (p * A * gamma / w) ** (1 / (1 - gamma))
    output = A * labor ** gamma
    return labor, output

def profits(w, p, A, gamma):
    labor, output = optimal_labor_output(w, p, A, gamma)
    profit = p * output - w * labor
    return profit

def consumer_behavior(w, p1, p2, tau, T, alpha, nu, epsilon, A, gamma):
    labor1, output1 = optimal_labor_output(w, p1, A, gamma)
    labor2, output2 = optimal_labor_output(w, p2 + tau, A, gamma)
    profit1 = profits(w, p1, A, gamma)
    profit2 = profits(w, p2, A, gamma)
    income = w * (labor1 + labor2) + T + profit1 + profit2
    c1 = alpha * income / p1
    c2 = (1 - alpha) * income / (p2 + tau)
    return labor1, labor2, output1, output2, c1, c2

def check_market_clearing_walras(w, p1_vals, p2_vals, par):
    results = []
    for p1 in p1_vals:
        for p2 in p2_vals:
            labor1, labor2, output1, output2, c1, c2 = consumer_behavior(
                w, p1, p2, par.tau, par.T, par.alpha, par.nu, par.epsilon, par.A, par.gamma
            )
            # We check labor market and Good 1 market clearing conditions
            labor_market_clearing = np.isclose(labor1 + labor2, labor1 + labor2)
            good_1_market_clearing = np.isclose(c1, output1)
            
            if labor_market_clearing and good_1_market_clearing:
                market_clearing = {
                    "p1": p1,
                    "p2": p2,
                    "Labor Market Clearing": labor_market_clearing,
                    "Good 1 Market Clearing": good_1_market_clearing,
                }
                results.append(market_clearing)
    return results

# Define the price ranges and numeraire
w = 1.0
p_vals = np.linspace(0.1, 2.0, 10)

# Find equilibrium prices using the check_market_clearing_walras function
market_clearing_results = check_market_clearing_walras(w, p_vals, p_vals, par)

# Print the market clearing results to debug
print("Market Clearing Results:", market_clearing_results)

# Convert the results to a DataFrame
market_clearing_df = pd.DataFrame(market_clearing_results)

# Print the DataFrame columns to debug
print("DataFrame Columns:", market_clearing_df.columns)

# Display the DataFrame with equilibrium prices
equilibrium_prices = market_clearing_df[
    (market_clearing_df["Labor Market Clearing"]) &
    (market_clearing_df["Good 1 Market Clearing"])
]

# Show the DataFrame with equilibrium prices
equilibrium_prices
# Out:
# Market Clearing Results: []
# DataFrame Columns: RangeIndex(start=0, stop=0, step=1)
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[58], line 75
#      71 print("DataFrame Columns:", market_clearing_df.columns)
#      73 # Display the DataFrame with equilibrium prices
#      74 equilibrium_prices = market_clearing_df[
# ---> 75     (market_clearing_df["Labor Market Clearing"]) &
#      76     (market_clearing_df["Good 1 Market Clearing"])
#      77 ]
#      79 # Show the DataFrame with equilibrium prices
#      80 equilibrium_prices
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\frame.py:4090, in DataFrame.__getitem__(self, key)
#    4088 if self.columns.nlevels > 1:
#    4089     return self._getitem_multilevel(key)
# -> 4090 indexer = self.columns.get_loc(key)
#    4091 if is_integer(indexer):
#    4092     indexer = [indexer]
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\indexes\range.py:417, in RangeIndex.get_loc(self, key)
#     415         raise KeyError(key) from err
#     416 if isinstance(key, Hashable):
# --> 417     raise KeyError(key)
#     418 self._check_indexing_error(key)
#     419 raise KeyError(key)
#
# KeyError: 'Labor Market Clearing'
